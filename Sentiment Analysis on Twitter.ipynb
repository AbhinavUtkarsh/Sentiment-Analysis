# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: pandas in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (0.23.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from pandas) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from pandas) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from pandas) (1.15.4)
# Requirement already satisfied: six>=1.5 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)
# Collecting tweepy
#   Using cached https://files.pythonhosted.org/packages/d5/5f/daac4b4e9b30d7d2a6fdd16a880ff79f27918fe388e4dfc1983dec3a9876/tweepy-3.7.0-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Using cached https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: PySocks>=1.5.7 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from tweepy) (2.21.0)
# Requirement already satisfied: six>=1.10.0 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from tweepy) (1.12.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy)
#   Using cached https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/abhinavutkarsh/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.24.1)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.0.1 requests-oauthlib-1.2.0 tweepy-3.7.0
# Collecting vaderSentiment
#   Using cached https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
import pandas as pd
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#Twitter API
consumer_key=""
consumer_secret=""
access_token=""
access_token_secret=""

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api=tweepy.API(auth)
tweets=api.search("Artificial Intelligence",count=200)
data=pd.DataFrame(data=[tweet.text for tweet in tweets],columns=['Tweets'])
display(data.head(10))
print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @MSFTResearch: Join researchers @JohnCKrumm...
# 1  RT @qdepim: "Former members of the US Departme...
# 2  Confs: William Davies Memorial Panel at ISLOJ ...
# 3  Khan Academy and Yup were great resources #art...
# 4  RT @CNN: Robot valets may soon park your car a...
# 5  Artificial intelligence in the spotlight (agai...
# 6  RT @bonglez: Artificial Intelligence is here -...
# 7  RT @LisaMei62: [They] are terrified...trying t...
# 8  RT @MikeQuindazzi: Artificial Intelligence sur...
# 9  RT @dennybritz: DeepMind (official): Our goal ...
# 2019-01-29 07:27:46

# %%
import nltk
nltk.download('lexicon')
# Out:
# [nltk_data] Error loading lexicon: Package 'lexicon' not found in
# [nltk_data]     index
# False

# %%
sid=SentimentIntensityAnalyzer()
listy=[]
for index, row in data.iterrows():
    ss=sid.polarity_scores(row["Tweets"])
    listy.append(ss)
se=pd.Series(listy)
data["Polarity"]=se.values
display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @MSFTResearch: Join researchers @JohnCKrumm...
# 1   RT @qdepim: "Former members of the US Departme...
# 2   Confs: William Davies Memorial Panel at ISLOJ ...
# 3   Khan Academy and Yup were great resources #art...
# 4   RT @CNN: Robot valets may soon park your car a...
# 5   Artificial intelligence in the spotlight (agai...
# 6   RT @bonglez: Artificial Intelligence is here -...
# 7   RT @LisaMei62: [They] are terrified...trying t...
# 8   RT @MikeQuindazzi: Artificial Intelligence sur...
# 9   RT @dennybritz: DeepMind (official): Our goal ...
# 10  RT @cnni: London's Gatwick Airport is testing ...
# 11  Nick Cave Answers the Hotly Debated Question: ...
# 12  RT @qdepim: THREAD: US &amp; KSA cyber warfare...
# 13  RT @WWalterego: Learning Math For Machine Lear...
# 14  What You Need to Know About the Future of the ...
# 15  Will Artificial Intelligence Soon Tell Us How ...
# 16  Hiring For The #AI Revolution\n\nhttps://t.co/...
# 17  RT @LisaMei62: [They] are terrified...trying t...
# 18  RT @SSA55_: Tha brand new tech launches, #IETF...
# 19  RT @kajodOnline: Excited for the 23rd edition ...
# 20  RT @CNN: London's Gatwick Airport is testing o...
# 21  BP Ventures has invested $5 million in Houston...
# 22  Advances in artificial intelligence could soon...
# 23  Do you want to know more about what SecOps can...
# 24  Blind spots in the artificial intelligence (AI...
# 25  RT @Volker_Straub: It can be difficult to squa...
# 26  How Artificial Intelligence (AI) shapes our li...
# 27  RT @salilsethi: Your thoughts about artificial...
# 28  https://t.co/xn67ZnHcPz on Monday good program...
# 29  @nekcne artificial intelligence #ArtificialInt...
# ..                                                ...
# 70  #IETF19 we are really looking forward to the 2...
# 71  RT @cnni: London's Gatwick Airport is testing ...
# 72  RT @FrRonconi: Hiring For The #AI (#Artificial...
# 73  RT @dinisguarda: The Geopolitics Of #AI #Artif...
# 74  RT @CNN: London's Gatwick Airport is testing o...
# 75  RT @AudreyDesisto: Hiring For The #AI (Artific...
# 76  preparing for the future of artificial intelli...
# 77  RT @invest_canada: In 2017, Canada launched a ...
# 78  RT @wordliftit: "If you run a blog or other te...
# 79  RT @CNN: London's Gatwick Airport is testing o...
# 80  RT @CNN: London's Gatwick Airport is testing o...
# 81  Up to 45-85% of sales tasks could be automated...
# 82  RT @BBCBusiness: Jeff Dean is the head of Arti...
# 83  RT @ModelGarima: I am really looking forward t...
# 84  RT @FlashTweet: 🔟[#Mustread] L'état de l'#IA e...
# 85  National Seminar on Artificial Intelligence an...
# 86  Japan's GPIF turns to artificial intelligence ...
# 87  Selepas 5-10 tahun,awak akan sedar..we are lea...
# 88  « Meet the scientists who are training AI to d...
# 89  RT @LisaMei62: [They] are terrified...trying t...
# 90  RT @ipfconline1: Demystifying #AI &amp; #Machi...
# 91  RT @UrbanLibCouncil: ULC's work on Artificial ...
# 92  RT @SwissCognitive: #AI used by adults, kids, ...
# 93  RT @ahvora: How Is Blockchain And Artificial I...
# 94  "Bias is a social problem, and seeking to solv...
# 95  RT @CNN: London's Gatwick Airport is testing o...
# 96  RT @CNN: London's Gatwick Airport is testing o...
# 97  RT @MikeQuindazzi: Artificial Intelligence sur...
# 98  RT @the_nhussain: 6 trends that will drive art...
# 99  RT @CNN: London's Gatwick Airport is testing o...
#
#                                              Polarity
# 0   {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'comp...
# 1   {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'comp...
# 2   {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'comp...
# 3   {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'comp...
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5   {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'comp...
# 6   {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
# 7   {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'comp...
# 8   {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...
# 9   {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 11  {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'comp...
# 12  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...
# 13  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...
# 14  {'neg': 0.0, 'neu': 0.772, 'pos': 0.228, 'comp...
# 15  {'neg': 0.108, 'neu': 0.731, 'pos': 0.161, 'co...
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 17  {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'comp...
# 18  {'neg': 0.051, 'neu': 0.761, 'pos': 0.188, 'co...
# 19  {'neg': 0.0, 'neu': 0.784, 'pos': 0.216, 'comp...
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 22  {'neg': 0.129, 'neu': 0.539, 'pos': 0.332, 'co...
# 23  {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'comp...
# 24  {'neg': 0.118, 'neu': 0.746, 'pos': 0.136, 'co...
# 25  {'neg': 0.219, 'neu': 0.781, 'pos': 0.0, 'comp...
# 26  {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 27  {'neg': 0.108, 'neu': 0.698, 'pos': 0.194, 'co...
# 28  {'neg': 0.0, 'neu': 0.553, 'pos': 0.447, 'comp...
# 29  {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'comp...
# ..                                                ...
# 70  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 71  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 72  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 73  {'neg': 0.141, 'neu': 0.859, 'pos': 0.0, 'comp...
# 74  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 75  {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'comp...
# 76  {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'comp...
# 77  {'neg': 0.0, 'neu': 0.919, 'pos': 0.081, 'comp...
# 78  {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'comp...
# 79  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 80  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 81  {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'comp...
# 82  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...
# 83  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 84  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 85  {'neg': 0.0, 'neu': 0.78, 'pos': 0.22, 'compou...
# 86  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
# 87  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
# 88  {'neg': 0.172, 'neu': 0.828, 'pos': 0.0, 'comp...
# 89  {'neg': 0.103, 'neu': 0.897, 'pos': 0.0, 'comp...
# 90  {'neg': 0.109, 'neu': 0.891, 'pos': 0.0, 'comp...
# 91  {'neg': 0.0, 'neu': 0.661, 'pos': 0.339, 'comp...
# 92  {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'comp...
# 93  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...
# 94  {'neg': 0.179, 'neu': 0.742, 'pos': 0.079, 'co...
# 95  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 96  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 97  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...
# 98  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 99  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [100 rows x 2 columns]
